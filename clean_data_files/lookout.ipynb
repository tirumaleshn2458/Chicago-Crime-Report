# %%
import pandas as pd
pd.set_option('display.max_columns',100)

# %%
data_frame=pd.read_csv('data.csv')

# %%
data_frame.head()
# Out:
#          ID Case Number                    Date                      Block  \
# 0   5741943    HN549294  08/25/2007 09:22:18 AM         074XX N ROGERS AVE
# 1     25953    JE240540  05/24/2021 03:06:00 PM        020XX N LARAMIE AVE
# 2     26038    JE279849  06/26/2021 09:24:00 AM      062XX N MC CORMICK RD
# 3  13279676    JG507211  11/09/2023 07:30:00 AM           019XX W BYRON ST
# 4  13274752    JG501049  11/12/2023 07:59:00 AM  086XX S COTTAGE GROVE AVE
#
#    IUCR Primary Type                                        Description  \
# 0  0560      ASSAULT                                             SIMPLE
# 1  0110     HOMICIDE                                FIRST DEGREE MURDER
# 2  0110     HOMICIDE                                FIRST DEGREE MURDER
# 3  0620     BURGLARY                                     UNLAWFUL ENTRY
# 4  0454      BATTERY  AGGRAVATED P.O. - HANDS, FISTS, FEET, NO / MIN...
#
#   Location Description  Arrest  Domestic  Beat  District  Ward  \
# ...

# %%
data_frame.shape
# Out:
# (7981711, 22)

# %%
data_frame.isnull().sum()/len(data_frame)*100
# Out:
# ID                      0.000000
# Case Number             0.000000
# Date                    0.000000
# Block                   0.000000
# IUCR                    0.000000
# Primary Type            0.000000
# Description             0.000000
# Location Description    0.154904
# Arrest                  0.000000
# Domestic                0.000000
# Beat                    0.000000
# District                0.000589
# Ward                    7.703286
# Community Area          7.686059
# FBI Code                0.000000
# X Coordinate            1.100604
# Y Coordinate            1.100604
# Year                    0.000000
# Updated On              0.000000
# Latitude                1.100604
# Longitude               1.100604
# Location                1.100604
# dtype: float64

# %% [markdown]
# 1. Visualize the trend patterns over the time.
# 2. Visualize overall, based on yr, months, weeks, day.
# 3. Highlight the keywords for each ward, area
# 4. Extract ward based on block

# %%
#clean the data by imputing the missing values in the entire dataset
